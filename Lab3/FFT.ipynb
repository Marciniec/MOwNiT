# %%
import numpy as np
import math
from matplotlib import pyplot as plt
import random

# %%
l = np.array([range(0,257)])

# %%
result = []
N= 256
for i in range(0,257):
    result.append(np.cos(4*np.pi*i/N)+np.cos(16*np.pi*i/N)/5+np.cos(32*np.pi*i/N)/8+np.cos(128*np.pi*i/N)/16)

# %%
plt.figure(figsize=(12,8))
plt.plot(range(0,257), result)
plt.show()

# %%
x = np.fft.rfft(result)

# %%
re, im = x.real, x.imag

# %%
plt.figure(figsize=(18, 8))
x = np.arange(len(re))
plt.bar(x, re, align = 'center', alpha = 0.5, color = 'red')
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.plot(np.linspace(0,250, num=1000), np.cos(4*np.pi*np.linspace(0,250, num=1000)/256), 'r')
plt.plot(np.linspace(0,250, num=1000), np.cos(16*np.pi*np.linspace(0,250, num=1000)/256)/5, 'b')
plt.plot(np.linspace(0,250, num=1000), np.cos(32*np.pi*np.linspace(0,250, num=1000)/256)/8, 'g')
plt.plot(np.linspace(0,250, num=1000), np.cos(128*np.pi*np.linspace(0,250, num=1000)/256)/16, 'black')

plt.show()

# %%
result2 =[]
N=256
for i in range(0,257):
    result2.append(np.cos(4*np.pi*i/N)+ random.random()/8.0)

# %%
plt.figure(figsize=(18,8))
plt.plot(result2)
plt.show()

# %%
x2 = np.fft.rfft(result2)

# %%
re2, img2 = x2.real, x2.imag
x2 = np.arange(len(re2))
plt.figure(figsize=(18,9))
plt.bar(x, re2, align = 'center', alpha = 0.5, color = 'green')
plt.show()

# %%
result3 = []
for r in re2:
    if abs(r) > 50:
        result3.append(r)
    else: 
        result3.append(0)

# %%
x2 = np.arange(len(result3))
plt.figure(figsize=(18,9))
plt.bar(x2, result3, align = 'center', alpha = 0.5, color = 'green')
plt.show()

# %%
ifft = np.fft.ifft(result3)

# %%
plt.figure(figsize=(11,7))
plt.plot(ifft.real)
plt.show()
